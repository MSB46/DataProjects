# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 100)

df = pd.read_csv("imdb_animated_movies.csv")
df.head()
# Out:
#                 name rating  runtime  \
# 0                  9  PG-13   79 min
# 1       A Bug's Life      G   95 min
# 2  A Christmas Carol     PG   96 min
# 3      A Goofy Movie      G   78 min
# 4   A Scanner Darkly      R  100 min
#
#                                               genres  \
# 0  Animation, Action, Adventure, Drama, Fantasy, ...
# 1      Animation, Adventure, Comedy, Family, Fantasy
# 2  Animation, Adventure, Comedy, Drama, Family, F...
# 3  Animation, Adventure, Comedy, Family, Musical,...
# 4  Animation, Comedy, Crime, Drama, Mystery, Sci-...
#
#                                           story_desc  votescore  metacritic  \
# 0  A rag doll that awakens in a postapocalyptic f...        7.0        60.0
# 1  A misfit ant, looking for "warriors" to save h...        7.2        77.0
# 2  An animated retelling of Charles Dickens' clas...        6.8        55.0
# 3  When Max makes a preposterous promise to a gir...        6.9        53.0
# 4  An undercover cop in a not-too-distant future ...        7.0        73.0
#
#                                 production_companies        year aspect_ratio  \
# 0  Focus Features, Relativity Media, Arc Productions  (I) (2009)     1.85 : 1
# 1      Pixar Animation Studios, Walt Disney Pictures  (I) (1998)     2.39 : 1
# 2  Walt Disney Pictures, ImageMovers Digital, Ima...      (2009)     2.39 : 1
# 3  Walt Disney Pictures, Disney Television Animat...      (1995)     1.85 : 1
# 4  Warner Independent Pictures (WIP), Thousand Wo...      (2006)     1.85 : 1
#
#                                     country languages    votes  \
# 0         United States, Canada, Luxembourg   English  141,553
# 1                             United States   English  295,606
# 2                             United States   English  120,272
# 3  United States, Australia, France, Canada   English   56,379
# 4                             United States   English  113,012
#
#   worldwide_gross      na_gross opening_weekend                budget_est  \
# 0     $48,428,063   $31,749,894     $10,740,446   $30,000,000 (estimated)
# 1    $363,258,859  $162,798,565        $291,121  $120,000,000 (estimated)
# 2    $325,286,646  $137,855,863     $30,051,075  $200,000,000 (estimated)
# 3     $35,348,597   $35,348,597      $6,129,557   $18,000,000 (estimated)
# 4      $7,659,918    $5,501,616        $391,672    $8,700,000 (estimated)
#
#                                        director  \
# 0                                 Shane Acker,
# 1  John Lasseter, Andrew Stanton(co-director),
# 2                             Robert Zemeckis,
# 3                                  Kevin Lima,
# 4                           Richard Linklater,
#
#                                              writers
# 0  Pamela Pettler(screenplay by), Shane Acker(sto...
# 1  John Lasseter(original story by), Andrew Stant...
# 2  Charles Dickens(based on the classic story by)...
# 3  Jymn Magon(story by), Chris Matheson(screenpla...
# 4  Philip K. Dick(novel "A Scanner Darkly"), Rich...

# %%
df.columns
# Out:
# Index(['name', 'rating', 'runtime', 'genres', 'story_desc', 'votescore',
#        'metacritic', 'production_companies', 'year', 'aspect_ratio', 'country',
#        'languages', 'votes', 'worldwide_gross', 'na_gross', 'opening_weekend',
#        'budget_est', 'director', 'writers'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 19

# %% [markdown]
# ## Primary columns to be modified/used
# * Rating -- All MPAA-relevant ratings
# * Runtime (minutes) -- Length of movie screening
# * Story description -- IMDb's description of the movie
# * Genres -- Any genre the movie is associated with besides Animation. May split into multiple columns.
#
#
# * votescore -- Score of movie based on user votes -> (Will be multiplied by 10 to align with metacritic score)
# * *metacritic -- Movie's Metacritic score
#
#
# * production companies -- Companies involved in making of the movie. Will be counted
# * year -> Year of movie's official release. Will be set to integer.
# * votes -> Amount of user votes affecting votescore of a movie. Will be set to an integer
#
#
#
# * *opening weekend -- Gross in the first week
# * *na gross -- North American gross (aka domestic gross)
# * *worldwide gross -- IMDb gross coverted to American currency. Into an integer
#
#
#
# * *budget -- Note every movie budget is recorded in the same currency (yen, euro, pound, dollar). Into an Integer.
# * May make two columns. One with original budget and another column with a budget converted to dollar currency
#
#
#
# * *aspect ratio -- Ratio of width and height of the movie shown.
# * countries -- Any countries involved with the making of the movie. Will be counted.
# * languages -- main/official languages translated for screenings/official releases. Will be counted.
#
# * director, writers -> Directors and writers involved in the making of the movie. Each will be counted.
#
#
#
# *Not every movie has a value for each column (may leave as -1 or n/a)

# %%
df.isnull().any()
# Out:
# name                    False
# rating                   True
# runtime                 False
# genres                  False
# story_desc               True
# votescore               False
# metacritic               True
# production_companies     True
# year                    False
# aspect_ratio             True
# country                 False
# languages               False
# votes                   False
# worldwide_gross         False
# na_gross                False
# opening_weekend         False
# budget_est              False
# director                False
# writers                  True
# dtype: bool

# %% [markdown]
# ### Handling null values for each column
# * Rating -> "Not Rated"
# * Metacritic -> -1
# * Any column involving currency -> -1
# * Production Companies -> "Unnamed"
# * Aspect Ratio -> N/A
# * Writers -> "Unspecified"

# %%
df.dtypes
# Out:
# name                     object
# rating                   object
# runtime                  object
# genres                   object
# story_desc               object
# votescore               float64
# metacritic              float64
# production_companies     object
# year                     object
# aspect_ratio             object
# country                  object
# languages                object
# votes                    object
# worldwide_gross          object
# na_gross                 object
# opening_weekend          object
# budget_est               object
# director                 object
# writers                  object
# dtype: object

# %% [markdown]
# ### Marking currencies
# IMDb typically uses the country a movie originates from as a reference for the currency used when specifying the budget's estimate. The goal here is to detect as many currencies found as possible so they can be used as another feature for the final dataframe.

# %%
df.insert(len(df.columns)-1, 'budget_est_usd',-1)
df.insert(len(df.columns)-1, 'orig_bgt_currency',-1)

# %%
df.iloc[250]
# Out:
# name                                                                Mulan
# rating                                                                  G
# runtime                                                            88 min
# genres                  Animation, Adventure, Comedy, Family, Fantasy,...
# story_desc              To save her father from death in the army, a y...
# votescore                                                             7.6
# metacritic                                                           71.0
# production_companies    Walt Disney Animation Studios, Walt Disney Fea...
# year                                                               (1998)
# aspect_ratio                                                          NaN
# country                                                     United States
# languages                                               English, Mandarin
# votes                                                             290,901
# worldwide_gross                                              $304,320,254
# na_gross                                                     $120,620,254
# opening_weekend                                               $22,745,143
# budget_est                                        $90,000,000 (estimated)
# director                                      Tony Bancroft, Barry Cook,
# budget_est_usd                                                         -1
# orig_bgt_currency                                                      -1
# writers                 Robert D. San Souci(based on a story by), Rita...
# Name: 250, dtype: object

# %%
print(df['budget_est'][250][:3])
print(df['budget_est'][226])
print(df['budget_est'][292])
# Out:
# $90
# $145,000,000 (estimated)
# $145,000,000 (estimated)

# %%
df['budget_est'] = df['budget_est'].apply(lambda x: x.split(" (")[0]).apply(lambda y: y.replace(" ",""))
# df['budget_est'] = df['budget_est'].apply(lambda x: x.replace(" ",""))

# %%
df['budget_est'][292]
# Out:
# '$145,000,000'

# %%
df['budget_est'][365]
# Out:
# '$125,000,000'

# %%
df['orig_bgt_currency'] = df['budget_est'].apply(lambda x: 'euro' if x[0] == '£' 
                                                 else ('yen' if x[0] == '¥' 
                                                       else ('pound' if x[0] == '€'
                                                             else ('austrailian dollar' if x[:2] == 'A$'
                                                                 else ('chinese yuan' if x[:3] == "CN¥"
                                                                       else ('danish krone' if x[:3] == "DKK"
                                                                             else ('poland zloty' if x[:3] == "PLN"
                                                                                   else 'usd')))))))

# %% [markdown]
# ### Removing currency mark from budget_est. Will be relocated to new column

# %%
df['budget_est'] = df['budget_est'].apply(lambda x: x[3:] if x[:3] == "CN¥"
                                          else (x[3:] if x[:3] == 'DKK'
                                                else (x[3:] if x[:3] == 'PLN'
                                                    else (x[2:] if x[:2] == 'A$'
                                                          else (x[1:] if x != '-1'
                                                                else -1))))).replace(',','', regex=True).astype(int)

# %% [markdown]
# ### Budget conversion to USD

# %%
for x in range(len(df)):
    if df['orig_bgt_currency'][x] == 'dollar':
        df['budget_est_usd'][x] = df['budget_est'][x]
    
    if df['orig_bgt_currency'][x] == 'pound':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 1.19)
    
    if df['orig_bgt_currency'][x] == 'euro':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 1.04)

    if df['orig_bgt_currency'][x] == 'austrailian dollar':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 0.67)
      
    if df['orig_bgt_currency'][x] == 'poland zloty':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 0.22)
    
    if df['orig_bgt_currency'][x] == 'chinese yuan' or 'danish krone':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 0.14)
        
    if df['orig_bgt_currency'][x] == 'yen':
        df['budget_est_usd'][x] = round(df['budget_est'][x] * 0.0072)
        
df.drop(['budget_est'], inplace=True, axis=1)

# %%
df['budget_est_usd'] = df['budget_est_usd'].apply(lambda x: -1 if x == 0 else x)

# %%
df.head(3)
# Out:
#                 name rating runtime  \
# 0                  9  PG-13  79 min
# 1       A Bug's Life      G  95 min
# 2  A Christmas Carol     PG  96 min
#
#                                               genres  \
# 0  Animation, Action, Adventure, Drama, Fantasy, ...
# 1      Animation, Adventure, Comedy, Family, Fantasy
# 2  Animation, Adventure, Comedy, Drama, Family, F...
#
#                                           story_desc  votescore  metacritic  \
# 0  A rag doll that awakens in a postapocalyptic f...        7.0        60.0
# 1  A misfit ant, looking for "warriors" to save h...        7.2        77.0
# 2  An animated retelling of Charles Dickens' clas...        6.8        55.0
#
#                                 production_companies        year aspect_ratio  \
# 0  Focus Features, Relativity Media, Arc Productions  (I) (2009)     1.85 : 1
# 1      Pixar Animation Studios, Walt Disney Pictures  (I) (1998)     2.39 : 1
# 2  Walt Disney Pictures, ImageMovers Digital, Ima...      (2009)     2.39 : 1
#
#                              country languages    votes worldwide_gross  \
# 0  United States, Canada, Luxembourg   English  141,553     $48,428,063
# 1                      United States   English  295,606    $363,258,859
# 2                      United States   English  120,272    $325,286,646
#
#        na_gross opening_weekend                                      director  \
# 0   $31,749,894     $10,740,446                                 Shane Acker,
# 1  $162,798,565        $291,121  John Lasseter, Andrew Stanton(co-director),
# 2  $137,855,863     $30,051,075                             Robert Zemeckis,
#
#    budget_est_usd orig_bgt_currency  \
# 0         4200000               usd
# 1        16800000               usd
# 2        28000000               usd
#
#                                              writers
# 0  Pamela Pettler(screenplay by), Shane Acker(sto...
# 1  John Lasseter(original story by), Andrew Stant...
# 2  Charles Dickens(based on the classic story by)...

# %% [markdown]
# ### Converting all monetary values to integer

# %%
def convert_int(s):
    return s.apply(lambda x: re.sub(',','',x[1:-1]) if not(x == -1) else -1).replace('','-1').astype(int)

# %%
df['worldwide_gross'] = convert_int(df['worldwide_gross'])

# %%
df = df.rename(columns={"worldwide_gross": "worldwide_gross_usd"})
df['worldwide_gross_usd'].head()
# Out:
# 0     4842806
# 1    36325885
# 2    32528664
# 3     3534859
# 4      765991
# Name: worldwide_gross_usd, dtype: int64

# %%
df['na_gross'] = convert_int(df['na_gross'])

# %%
df = df.rename(columns={"na_gross": "na_gross_usd"})

# %%
df['opening_weekend'] = convert_int(df['opening_weekend'])

# %%
df = df.rename(columns={"opening_weekend": "opening_weekend_usd"})

# %%
df.na_gross_usd
# Out:
# 0       3174989
# 1      16279856
# 2      13785586
# 3       3534859
# 4        550161
#          ...
# 469    18942288
# 470       99230
# 471    10024601
# 472    34126824
# 473          -1
# Name: na_gross_usd, Length: 474, dtype: int64

# %% [markdown]
# ### Getting profit data

# %%
df.insert(len(df.columns)-1, 'profit_usd', -9)
for x in range(len(df)):
    if (df['budget_est_usd'][x] > -1) and (df['worldwide_gross_usd'][x] > -1):
        df['profit_usd'][x] = df['worldwide_gross_usd'][x] - df['budget_est_usd'][x]
    else:
        df['profit_usd'][x] = -1

# %%
type(df.profit_usd)
# Out:
# pandas.core.series.Series

# %%
df['profit_usd'].tail(3)
# Out:
# 471     9150937
# 472    83253368
# 473          -1
# Name: profit_usd, dtype: int64

# %% [markdown]
# ### Converting columns to appropriate data types

# %%
df['votes'] = df['votes'].replace(',','', regex=True).astype(int)

# %%
df['year'].astype(str)
# Out:
# 0      (I) (2009)
# 1      (I) (1998)
# 2          (2009)
# 3          (1995)
# 4          (2006)
#           ...
# 469        (2012)
# 470        (1968)
# 471        (2010)
# 472        (2016)
# 473        (2012)
# Name: year, Length: 474, dtype: object

# %%
df['year'] = df['year'].apply(lambda x: re.sub('\D', '', x).strip()).astype(int)

# %%
year_column = df.pop("year")
# insert column with insert(location, column_name, column_value)

df.insert(2, "year", year_column)

# %%
df['year'].head(10)
# Out:
# 0    2009
# 1    1998
# 2    2009
# 3    1995
# 4    2006
# 5    2019
# 6    2019
# 7    1988
# 8    1992
# 9    1951
# Name: year, dtype: int64

# %%
df['votescore'].astype(float)
# Out:
# 0      7.0
# 1      7.2
# 2      6.8
# 3      6.9
# 4      7.0
#       ...
# 469    7.7
# 470    7.4
# 471    4.6
# 472    8.0
# 473    8.1
# Name: votescore, Length: 474, dtype: float64

# %%
df['votescore'] = round(df['votescore']  * 10,1)

# %%
df['votescore'].head(3)
# Out:
# 0    70.0
# 1    72.0
# 2    68.0
# Name: votescore, dtype: float64

# %%
df['metacritic'].fillna(-1,inplace=True)
df['metacritic'].head(3)
# Out:
# 0    60.0
# 1    77.0
# 2    55.0
# Name: metacritic, dtype: float64

# %%
df.insert(6,'avg_rating_score', 0)

# %%
for x in range(len(df)):
    if df['metacritic'][x] != -1:
        df['avg_rating_score'][x] = (df['votescore'][x] + df['metacritic'][x]) / 2
    else:
        df['avg_rating_score'][x] = df['votescore'][x]

# %%
df['avg_rating_score']
# Out:
# 0      65.0
# 1      74.5
# 2      61.5
# 3      61.0
# 4      71.5
#        ...
# 469    74.5
# 470    76.5
# 471    40.5
# 472    79.0
# 473    76.0
# Name: avg_rating_score, Length: 474, dtype: float64

# %% [markdown]
# ### Production companies

# %%
df['production_companies'].fillna('Unnamed',inplace=True)

df.insert(9, "prod_company_count", 0)
df['prod_company_count'] =  df['production_companies'].apply(lambda x: x.count(",") + 1)

# %%
df[{'production_companies','prod_company_count'}].head(5)
# Out:
#                                 production_companies  prod_company_count
# 0  Focus Features, Relativity Media, Arc Productions                   3
# 1      Pixar Animation Studios, Walt Disney Pictures                   2
# 2  Walt Disney Pictures, ImageMovers Digital, Ima...                   3
# 3  Walt Disney Pictures, Disney Television Animat...                   3
# 4  Warner Independent Pictures (WIP), Thousand Wo...                   3

# %% [markdown]
# ### Countries and Languages

# %%
df.insert(13,'country_count', 0)
df.insert(15,'language_count', 0)

for x in range(len(df)):
    df['country_count'][x] = df['country'][x].count(",")+1
    df['language_count'][x] = df['languages'][x].count(",")+1

# %%
df = df.rename(columns={"country": "production_countries"})

# %%
df[{'production_countries','country_count','languages','language_count','name'}]
# Out:
#                          production_countries languages               name  \
# 0           United States, Canada, Luxembourg   English                  9
# 1                               United States   English       A Bug's Life
# 2                               United States   English  A Christmas Carol
# 3    United States, Australia, France, Canada   English      A Goofy Movie
# 4                               United States   English   A Scanner Darkly
# ..                                        ...       ...                ...
# 469                             United States   English     Wreck-It Ralph
# 470             United Kingdom, United States   English   Yellow Submarine
# 471                United States, New Zealand   English          Yogi Bear
# 472                             United States   English           Zootopia
# 473                                     Japan  Japanese      Wolf Children
#
#      country_count  language_count
# 0                3               1
# 1                1               1
# 2                1               1
# 3                4               1
# 4                1               1
# ..             ...             ...
# 469              1               1
# 470              2               1
# 471              2               1
# 472              1               1
# 473              1               1
#
# [474 rows x 5 columns]

# %% [markdown]
# ### Aspect Ratio

# %%
df['aspect_ratio'].fillna("Unspecified",inplace=True)

# %% [markdown]
# ### MPAA Ratings

# %%
df.rating.unique()
# Out:
# array(['PG-13', 'G', 'PG', 'R', 'Approved', 'Not Rated', 'TV-Y7-FV', nan,
#        'TV-14', 'TV-MA', 'TV-PG', '18+'], dtype=object)

# %%
df[df['rating'] == "Approved"]
# Out:
#                                        name    rating  year runtime  \
# 20                              Animal Farm  Approved  1954  72 min
# 323         Snow White and the Seven Dwarfs  Approved  1937  83 min
# 355  The Adventures of Ichabod and Mr. Toad  Approved  1949  68 min
# 428                    The Three Caballeros  Approved  1944  71 min
#
#                                                 genres  \
# 20                                    Animation, Drama
# 323  Animation, Adventure, Family, Fantasy, Musical...
# 355         Animation, Comedy, Family, Fantasy, Horror
# 428        Animation, Comedy, Family, Fantasy, Musical
#
#                                             story_desc  avg_rating_score  \
# 20   A successful farmyard revolution by the reside...              72.0
# 323  Exiled into the dangerous forest by her wicked...              86.0
# 355  An animated adaptation of "The Wind in the Wil...              71.5
# 428  Donald receives his birthday gifts, which incl...              74.0
#
#      votescore  metacritic  prod_company_count  \
# 20        72.0        -1.0                   2
# 323       76.0        96.0                   1
# 355       69.0        74.0                   1
# 428       63.0        85.0                   1
#
#                                   production_companies aspect_ratio  \
# 20   Halas & Batchelor, Central Intelligence Agency...  Unspecified
# 323                      Walt Disney Animation Studios          4:3
# 355                      Walt Disney Animation Studios     1.37 : 1
# 428                      Walt Disney Animation Studios     1.37 : 1
#
#               production_countries  country_count  \
# 20   United Kingdom, United States              2
# 323                  United States              1
# 355                  United States              1
# 428                  United States              1
#
#                         languages  language_count   votes  \
# 20                        English               1   17679
# 323                       English               1  201683
# 355                       English               1   16307
# 428  English, Spanish, Portuguese               3   14456
#
#      worldwide_gross_usd  na_gross_usd  opening_weekend_usd  \
# 20                    -1            -1                   -1
# 323             18492548      18492548               601791
# 355                   -1            -1                   -1
# 428                   -1            -1                   -1
#
#                                               director  budget_est_usd  \
# 20                         Joy Batchelor, John Halas,               -1
# 323  William Cottrell(sequence director), David Han...          209860
# 355         James Algar, Clyde Geronimi, Jack Kinney,               -1
# 428  Norman Ferguson, Clyde Geronimi(sequence direc...              -1
#
#     orig_bgt_currency  profit_usd  \
# 20                usd          -1
# 323               usd    18282688
# 355               usd          -1
# 428               usd          -1
#
#                                                writers
# 20   George Orwell(based on a story by), Lothar Wol...
# 323  Jacob Grimm(fairy tales), Wilhelm Grimm(fairy ...
# 355  Washington Irving(story "The Legend of Sleepy ...
# 428  Homer Brightman(story), Ernest Terrazas(story)...

# %%
df['rating'].fillna('Not Rated',inplace=True)
df.rating.unique()
# Out:
# array(['PG-13', 'G', 'PG', 'R', 'Approved', 'Not Rated', 'TV-Y7-FV',
#        'TV-14', 'TV-MA', 'TV-PG', '18+'], dtype=object)

# %% [markdown]
# ### Genres

# %%
df['genres'] = df['genres'].replace("Animation, ","", regex=True)

# %%
df['genres']
# Out:
# 0      Action, Adventure, Drama, Fantasy, Sci-Fi, Thr...
# 1                     Adventure, Comedy, Family, Fantasy
# 2              Adventure, Comedy, Drama, Family, Fantasy
# 3            Adventure, Comedy, Family, Musical, Romance
# 4        Comedy, Crime, Drama, Mystery, Sci-Fi, Thriller
#                              ...
# 469           Adventure, Comedy, Family, Fantasy, Sci-Fi
# 470                  Adventure, Comedy, Fantasy, Musical
# 471                            Adventure, Comedy, Family
# 472            Adventure, Comedy, Crime, Family, Mystery
# 473                               Drama, Family, Fantasy
# Name: genres, Length: 474, dtype: object

# %%
df.insert(5, "genre_count", 0)

for x in range(len(df)):
    # Genres not including Animation
    df['genre_count'][x] = df['genres'][x].count(",")+1
    
df['genre_count']
# Out:
# 0      6
# 1      4
# 2      5
# 3      5
# 4      6
#       ..
# 469    5
# 470    4
# 471    3
# 472    5
# 473    3
# Name: genre_count, Length: 474, dtype: int64

# %% [markdown]
# ### Story description

# %%
df['story_desc'].fillna("-9",inplace=True)

# %%
df.iloc[224]
# Out:
# name                                                             Cat City
# rating                                                          Not Rated
# year                                                                 1986
# runtime                                                            96 min
# genres                           Adventure, Comedy, Crime, Family, Sci-Fi
# genre_count                                                             5
# story_desc                                                             -9
# avg_rating_score                                                     83.0
# votescore                                                            83.0
# metacritic                                                           -1.0
# prod_company_count                                                      3
# production_companies    Pannónia Filmstúdió, Sefel Pictures Internatio...
# aspect_ratio                                                     1.37 : 1
# production_countries                        Hungary, Canada, West Germany
# country_count                                                           3
# languages                                                       Hungarian
# language_count                                                          1
# votes                                                               10147
# worldwide_gross_usd                                                  1493
# na_gross_usd                                                           -1
# opening_weekend_usd                                                    -1
# director                                                Béla Ternovszky,
# budget_est_usd                                                         -1
# orig_bgt_currency                                                     usd
# profit_usd                                                             -1
# writers                                                     József Nepp,
# Name: 224, dtype: object

# %%
for x in range(len(df)):
    print(f"{x}{type(df['story_desc'][x])}")
# Out:
# 0<class 'str'>
# 1<class 'str'>
# 2<class 'str'>
# 3<class 'str'>
# 4<class 'str'>
# 5<class 'str'>
# 6<class 'str'>
# 7<class 'str'>
# 8<class 'str'>
# 9<class 'str'>
# 10<class 'str'>
# 11<class 'str'>
# 12<class 'str'>
# 13<class 'str'>
# 14<class 'str'>
# 15<class 'str'>
# 16<class 'str'>
# 17<class 'str'>
# 18<class 'str'>
# 19<class 'str'>
# 20<class 'str'>
# 21<class 'str'>
# 22<class 'str'>
# 23<class 'str'>
# 24<class 'str'>
# 25<class 'str'>
# 26<class 'str'>
# 27<class 'str'>
# 28<class 'str'>
# 29<class 'str'>
# 30<class 'str'>
# 31<class 'str'>
# 32<class 'str'>
# 33<class 'str'>
# 34<class 'str'>
# 35<class 'str'>
# 36<class 'str'>
# 37<class 'str'>
# 38<class 'str'>
# 39<class 'str'>
# 40<class 'str'>
# 41<class 'str'>
# 42<class 'str'>
# 43<class 'str'>
# 44<class 'str'>
# 45<class 'str'>
# 46<class 'str'>
# 47<class 'str'>
# 48<class 'str'>
# 49<class 'str'>
# 50<class 'str'>
# 51<class 'str'>
# 52<class 'str'>
# 466<class 'str'>
# 467<class 'str'>
# 468<class 'str'>
# 469<class 'str'>
# 470<class 'str'>
# 471<class 'str'>
# 472<class 'str'>
# 473<class 'str'>

# %%
df.insert(7, "story_word_count", 0)

for x in range(len(df)):
    if df['story_desc'][x] == "-9":
        continue
    df['story_word_count'][x] = df['story_desc'][x].count(" ")+1

# %% [markdown]
# ### Runtime

# %%
df = df.rename(columns={"runtime": "runtime_minutes"})
df.head()
# Out:
#                 name rating  year runtime_minutes  \
# 0                  9  PG-13  2009          79 min
# 1       A Bug's Life      G  1998          95 min
# 2  A Christmas Carol     PG  2009          96 min
# 3      A Goofy Movie      G  1995          78 min
# 4   A Scanner Darkly      R  2006         100 min
#
#                                               genres  genre_count  \
# 0  Action, Adventure, Drama, Fantasy, Sci-Fi, Thr...            6
# 1                 Adventure, Comedy, Family, Fantasy            4
# 2          Adventure, Comedy, Drama, Family, Fantasy            5
# 3        Adventure, Comedy, Family, Musical, Romance            5
# 4    Comedy, Crime, Drama, Mystery, Sci-Fi, Thriller            6
#
#                                           story_desc  story_word_count  \
# 0  A rag doll that awakens in a postapocalyptic f...                15
# 1  A misfit ant, looking for "warriors" to save h...                27
# 2  An animated retelling of Charles Dickens' clas...                24
# 3  When Max makes a preposterous promise to a gir...                34
# 4  An undercover cop in a not-too-distant future ...                24
#
#    avg_rating_score  votescore  metacritic  prod_company_count  \
# 0              65.0       70.0        60.0                   3
# 1              74.5       72.0        77.0                   2
# 2              61.5       68.0        55.0                   3
# 3              61.0       69.0        53.0                   3
# 4              71.5       70.0        73.0                   3
#
#                                 production_companies aspect_ratio  \
# 0  Focus Features, Relativity Media, Arc Productions     1.85 : 1
# 1      Pixar Animation Studios, Walt Disney Pictures     2.39 : 1
# 2  Walt Disney Pictures, ImageMovers Digital, Ima...     2.39 : 1
# 3  Walt Disney Pictures, Disney Television Animat...     1.85 : 1
# 4  Warner Independent Pictures (WIP), Thousand Wo...     1.85 : 1
#
#                        production_countries  country_count languages  \
# 0         United States, Canada, Luxembourg              3   English
# 1                             United States              1   English
# 2                             United States              1   English
# 3  United States, Australia, France, Canada              4   English
# 4                             United States              1   English
#
#    language_count   votes  worldwide_gross_usd  na_gross_usd  \
# 0               1  141553              4842806       3174989
# 1               1  295606             36325885      16279856
# 2               1  120272             32528664      13785586
# 3               1   56379              3534859       3534859
# 4               1  113012               765991        550161
#
#    opening_weekend_usd                                      director  \
# 0              1074044                                 Shane Acker,
# 1                29112  John Lasseter, Andrew Stanton(co-director),
# 2              3005107                             Robert Zemeckis,
# 3               612955                                  Kevin Lima,
# 4                39167                           Richard Linklater,
#
#    budget_est_usd orig_bgt_currency  profit_usd  \
# 0         4200000               usd      642806
# 1        16800000               usd    19525885
# 2        28000000               usd     4528664
# 3         2520000               usd     1014859
# 4         1218000               usd     -452009
#
#                                              writers
# 0  Pamela Pettler(screenplay by), Shane Acker(sto...
# 1  John Lasseter(original story by), Andrew Stant...
# 2  Charles Dickens(based on the classic story by)...
# 3  Jymn Magon(story by), Chris Matheson(screenpla...
# 4  Philip K. Dick(novel "A Scanner Darkly"), Rich...

# %%
df['runtime_minutes'] = df['runtime_minutes'].replace('min','', regex=True).astype(int)
df['runtime_minutes']
# Out:
# 0       79
# 1       95
# 2       96
# 3       78
# 4      100
#       ...
# 469    101
# 470     85
# 471     80
# 472    108
# 473    117
# Name: runtime_minutes, Length: 474, dtype: int64

# %% [markdown]
# ### Some more feature engineering

# %%
df.insert(19,'avg_usd_budget_per_minute', -1)

# %%
for x in range(len(df)):
    if df['budget_est_usd'][x] != -1:
        df['avg_usd_budget_per_minute'][x] = round(df['budget_est_usd'][x]/df['runtime_minutes'][x],2)
    else:
        df['budget_est_usd'][x] = -1

# %%
df[{'budget_est_usd','runtime_minutes','avg_usd_budget_per_minute'}].tail(10)
# Out:
#      budget_est_usd  avg_usd_budget_per_minute  runtime_minutes
# 464         4200000                   66666.67               63
# 465              -1                      -1.00               98
# 466          168000                    2100.00               80
# 467         1680000                   16310.68              103
# 468        12600000                  148235.29               85
# 469        23100000                  228712.87              101
# 470           35000                     411.76               85
# 471        11200000                  140000.00               80
# 472        21000000                  194444.44              108
# 473              -1                      -1.00              117

# %% [markdown]
# ### Directors

# %%
dir_column = df.pop("director")
# insert column with insert(location, column_name, column_value)

df.insert(len(df.columns)-1, "directors", dir_column)

# %%
df['directors'] = df['directors'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", str(x)))
df['writers'] = df['writers'].apply(lambda x: re.sub("[\(\[].*?[\)\]]", "", str(x)) if x is not None else "Unspecified")

# %%
df[df['writers'] == "Unspecified"]
# Out:
# Empty DataFrame
# Columns: [name, rating, year, runtime_minutes, genres, genre_count, story_desc, story_word_count, avg_rating_score, votescore, metacritic, prod_company_count, production_companies, aspect_ratio, production_countries, country_count, languages, language_count, votes, avg_usd_budget_per_minute, worldwide_gross_usd, na_gross_usd, opening_weekend_usd, budget_est_usd, orig_bgt_currency, profit_usd, directors, writers]
# Index: []

# %%
df['directors'] = df['directors'].str.rstrip(", ")
df['writers'] = df['writers'].str.rstrip(", ")

# %%
df.insert(len(df.columns)-1, "director_count", 0)
df.insert(len(df.columns), "writer_count", 0)

for x in range(len(df)):
    df['director_count'][x] = df['directors'][x].count(",")+1
    df['writer_count'][x] = df['writers'][x].count(",")+1

# %%
df.isnull().any()
# Out:
# name                         False
# rating                       False
# year                         False
# runtime_minutes              False
# genres                       False
# genre_count                  False
# story_desc                   False
# story_word_count             False
# avg_rating_score             False
# votescore                    False
# metacritic                   False
# prod_company_count           False
# production_companies         False
# aspect_ratio                 False
# production_countries         False
# country_count                False
# languages                    False
# language_count               False
# votes                        False
# avg_usd_budget_per_minute    False
# worldwide_gross_usd          False
# na_gross_usd                 False
# opening_weekend_usd          False
# budget_est_usd               False
# orig_bgt_currency            False
# profit_usd                   False
# directors                    False
# director_count               False
# writers                      False
# writer_count                 False
# dtype: bool

# %%
df.dtypes
# Out:
# name                          object
# rating                        object
# year                           int64
# runtime_minutes                int64
# genres                        object
# genre_count                    int64
# story_desc                    object
# story_word_count               int64
# avg_rating_score             float64
# votescore                    float64
# metacritic                   float64
# prod_company_count             int64
# production_companies          object
# aspect_ratio                  object
# production_countries          object
# country_count                  int64
# languages                     object
# language_count                 int64
# votes                          int64
# avg_usd_budget_per_minute    float64
# worldwide_gross_usd            int64
# na_gross_usd                   int64
# opening_weekend_usd            int64
# budget_est_usd                 int64
# orig_bgt_currency             object
# profit_usd                     int64
# directors                     object
# director_count                 int64
# writers                       object
# writer_count                   int64
# dtype: object

# %%
df
# Out:
#                   name rating  year  runtime_minutes  \
# 0                    9  PG-13  2009               79
# 1         A Bug's Life      G  1998               95
# 2    A Christmas Carol     PG  2009               96
# 3        A Goofy Movie      G  1995               78
# 4     A Scanner Darkly      R  2006              100
# ..                 ...    ...   ...              ...
# 469     Wreck-It Ralph     PG  2012              101
# 470   Yellow Submarine      G  1968               85
# 471          Yogi Bear     PG  2010               80
# 472           Zootopia     PG  2016              108
# 473      Wolf Children     PG  2012              117
#
#                                                 genres  genre_count  \
# 0    Action, Adventure, Drama, Fantasy, Sci-Fi, Thr...            6
# 1                   Adventure, Comedy, Family, Fantasy            4
# 2            Adventure, Comedy, Drama, Family, Fantasy            5
# 3          Adventure, Comedy, Family, Musical, Romance            5
# 4      Comedy, Crime, Drama, Mystery, Sci-Fi, Thriller            6
# ..                                                 ...          ...
# 469         Adventure, Comedy, Family, Fantasy, Sci-Fi            5
# 470                Adventure, Comedy, Fantasy, Musical            4
# 471                          Adventure, Comedy, Family            3
# 472          Adventure, Comedy, Crime, Family, Mystery            5
# 473                             Drama, Family, Fantasy            3
#
#                                             story_desc  story_word_count  \
# 0    A rag doll that awakens in a postapocalyptic f...                15
# 1    A misfit ant, looking for "warriors" to save h...                27
# 2    An animated retelling of Charles Dickens' clas...                24
# 3    When Max makes a preposterous promise to a gir...                34
# 4    An undercover cop in a not-too-distant future ...                24
# ..                                                 ...               ...
# 469  A video game villain wants to be a hero and se...                28
# 470  The Beatles agree to accompany Captain Fred in...                23
# 471  A documentary filmmaker travels to Jellystone ...                24
# 472  In a city of anthropomorphic animals, a rookie...                23
# 473  After her werewolf lover unexpectedly dies in ...                41
#
#      avg_rating_score  votescore  metacritic  prod_company_count  \
# 0                65.0       70.0        60.0                   3
# 1                74.5       72.0        77.0                   2
# 2                61.5       68.0        55.0                   3
# 3                61.0       69.0        53.0                   3
# 4                71.5       70.0        73.0                   3
# ..                ...        ...         ...                 ...
# 469              74.5       77.0        72.0                   2
# 470              76.5       74.0        79.0                   3
# 471              40.5       46.0        35.0                   3
# 472              79.0       80.0        78.0                   2
# 473              76.0       81.0        71.0                   3
#
#                                   production_companies aspect_ratio  \
# 0    Focus Features, Relativity Media, Arc Productions     1.85 : 1
# 1        Pixar Animation Studios, Walt Disney Pictures     2.39 : 1
# 2    Walt Disney Pictures, ImageMovers Digital, Ima...     2.39 : 1
# 3    Walt Disney Pictures, Disney Television Animat...     1.85 : 1
# 4    Warner Independent Pictures (WIP), Thousand Wo...     1.85 : 1
# ..                                                 ...          ...
# 469  Walt Disney Animation Studios, Walt Disney Pic...     2.39 : 1
# 470   Apple Corps, King Features Syndicate, TVC London     1.66 : 1
# 471  Warner Bros., Sunswept Entertainment, De Line ...     1.85 : 1
# 472  Walt Disney Pictures, Walt Disney Animation St...     2.39 : 1
# 473  Nippon Television Network (NTV), Studio Chizu,...     1.85 : 1
#
#                          production_countries  country_count languages  \
# 0           United States, Canada, Luxembourg              3   English
# 1                               United States              1   English
# 2                               United States              1   English
# 3    United States, Australia, France, Canada              4   English
# 4                               United States              1   English
# ..                                        ...            ...       ...
# 469                             United States              1   English
# 470             United Kingdom, United States              2   English
# 471                United States, New Zealand              2   English
# 472                             United States              1   English
# 473                                     Japan              1  Japanese
#
#      language_count   votes  avg_usd_budget_per_minute  worldwide_gross_usd  \
# 0                 1  141553                   53164.56              4842806
# 1                 1  295606                  176842.11             36325885
# 2                 1  120272                  291666.67             32528664
# 3                 1   56379                   32307.69              3534859
# 4                 1  113012                   12180.00               765991
# ..              ...     ...                        ...                  ...
# 469               1  425919                  228712.87             47122288
# 470               1   26705                     411.76               127326
# 471               1   22349                  140000.00             20350937
# 472               1  501967                  194444.44            104253368
# 473               1   45631                      -1.00              5499977
#
#      na_gross_usd  opening_weekend_usd  budget_est_usd orig_bgt_currency  \
# 0         3174989              1074044         4200000               usd
# 1        16279856                29112        16800000               usd
# 2        13785586              3005107        28000000               usd
# 3         3534859               612955         2520000               usd
# 4          550161                39167         1218000               usd
# ..            ...                  ...             ...               ...
# 469      18942288              4903871        23100000               usd
# 470         99230                10710           35000              euro
# 471      10024601              1641132        11200000               usd
# 472      34126824              7506340        21000000               usd
# 473            -1                   -1              -1               usd
#
#      profit_usd                             directors  director_count  \
# 0        642806                           Shane Acker               1
# 1      19525885         John Lasseter, Andrew Stanton               2
# 2       4528664                       Robert Zemeckis               1
# 3       1014859                            Kevin Lima               1
# 4       -452009                     Richard Linklater               1
# ..          ...                                   ...             ...
# 469    24022288                            Rich Moore               1
# 470       92326                        George Dunning               1
# 471     9150937                           Eric Brevig               1
# 472    83253368  Byron Howard, Rich Moore, Jared Bush               3
# 473          -1                         Mamoru Hosoda               1
#
#                                                writers  writer_count
# 0               Pamela Pettler, Shane Acker, Ben Gluck             3
# 1             John Lasseter, Andrew Stanton, Joe Ranft             3
# 2                     Charles Dickens, Robert Zemeckis             2
# 3           Jymn Magon, Chris Matheson, Brian Pimental             3
# 4                    Philip K. Dick, Richard Linklater             2
# ..                                                 ...           ...
# 469             Rich Moore, Phil Johnston, Jim Reardon             3
# 470            Lee Minoff, John Lennon, Paul McCartney             3
# 471  Jennifer Ventimilia, Joshua Sternin, Brad Cope...             3
# 472               Byron Howard, Rich Moore, Jared Bush             3
# 473                      Mamoru Hosoda, Satoko Okudera             2
#
# [474 rows x 30 columns]

# %%
df.to_csv("imdb_animated_movies_clean.csv", index = False)
